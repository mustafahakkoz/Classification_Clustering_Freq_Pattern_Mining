# %% [markdown]
# # Frequent Pattern Mining
# CSE4063 - Data Mining Project-2

# %%
# import packages
import tracemalloc
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
import time
import linecache
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# Empty items are removed later

# %%
with open('../input/freqmining/cse4063-spring2020-project-2-dataset-fpm.csv', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)
data[:10]
# Out:
# [['Lassi', 'Coffee Powder', 'Butter', 'Yougurt', 'Ghee', 'Cheese', ''],
#  ['Ghee', 'Coffee Powder', ''],
#  ['Lassi', 'Tea Powder', 'Butter', 'Cheese', ''],
#  ['Cheese', 'Tea Powder', 'Panner', 'Coffee Powder', 'Butter', 'Bread', ''],
#  ['Cheese', 'Yougurt', 'Coffee Powder', 'Sugar', 'Butter', 'Sweet', ''],
#  ['Sugar', 'Tea Powder', 'Ghee', 'Sweet', 'Panner', 'Milk', ''],
#  ['Sweet', 'Coffee Powder', ''],
#  ['Butter', 'Ghee', 'Panner', ''],
#  ['Sweet', 'Tea Powder', 'Butter', 'Yougurt', 'Sugar', 'Cheese', ''],
#  ['Panner', 'Ghee', '']]

# %% [markdown]
#  Displays memory usage for given function name

# %%
def calculate_mem_use(snapshot, key_type='lineno', func=""):
    snapshot = snapshot.filter_traces((
        tracemalloc.Filter(False, "<frozen importlib._bootstrap>"),
        tracemalloc.Filter(False, "<unknown>"),
    ))
    top_stats = snapshot.statistics(key_type)
    total = 0
    for index, stat in enumerate(top_stats, 1):
        frame = stat.traceback[0]
        if func in frame.filename or "data" in frame.filename:
            total = total + stat.size
    return total

# %% [markdown]
# # **Prepare data**

# %%
te = TransactionEncoder()
te_ary = te.fit(data).transform(data)
df = pd.DataFrame(te_ary, columns=te.columns_)
del df[""]  # remove empty item
df
# Out:
#        Bread  Butter  Cheese  Coffee Powder   Ghee  Lassi   Milk  Panner  \
# 0      False    True    True           True   True   True  False   False
# 1      False   False   False           True   True  False  False   False
# 2      False    True    True          False  False   True  False   False
# 3       True    True    True           True  False  False  False    True
# 4      False    True    True           True  False  False  False   False
# ...      ...     ...     ...            ...    ...    ...    ...     ...
# 12521   True   False    True          False  False  False   True    True
# 12522   True   False    True           True  False  False  False   False
# 12523   True   False    True          False  False  False   True   False
# 12524   True   False    True          False   True  False  False   False
# 12525   True   False   False          False  False  False  False    True
#
#        Sugar  Sweet  Tea Powder  Yougurt
# 0      False  False       False     True
# 1      False  False       False    False
# 2      False  False        True    False
# 3      False  False        True    False
# 4       True   True       False     True
# ...      ...    ...         ...      ...
# 12521   True  False       False    False
# 12522   True  False       False    False
# 12523  False  False       False     True
# 12524   True  False       False     True
# 12525  False  False       False     True
#
# [12526 rows x 12 columns]

# %% [markdown]
# # **Apriori**

# %%
start = time.time()
tracemalloc.start()
df_apriori = apriori(df, min_support=0.2, use_colnames=True)    
snapshot = tracemalloc.take_snapshot()
done = time.time()
elapsed = done - start
mem_use = calculate_mem_use(snapshot, func="apriori")
print("Mem. use : %1.f B" %(mem_use))
print("Elapsed Time : ",elapsed," sn")
df_apriori
# Out:
# Mem. use : 17678 B
# Elapsed Time :  0.022913694381713867  sn
#      support                  itemsets
# 0   0.437809                   (Bread)
# 1   0.437570                  (Butter)
# 2   0.437171                  (Cheese)
# 3   0.439805           (Coffee Powder)
# 4   0.439885                    (Ghee)
# 5   0.433658                   (Lassi)
# 6   0.441162                    (Milk)
# 7   0.434616                  (Panner)
# 8   0.437650                   (Sugar)
# 9   0.437730                   (Sweet)
# 10  0.429746              (Tea Powder)
# 11  0.439326                 (Yougurt)
# 12  0.201980           (Cheese, Bread)
# 13  0.201820    (Coffee Powder, Bread)
# 14  0.200064            (Lassi, Bread)
# 15  0.200942             (Milk, Bread)
# 16  0.203577           (Panner, Bread)
# 17  0.202698            (Sweet, Bread)
# 18  0.200144          (Yougurt, Bread)
# 19  0.201980            (Butter, Ghee)
# 20  0.205253           (Butter, Sugar)
# 21  0.203018           (Butter, Sweet)
# 22  0.201900         (Butter, Yougurt)
# 23  0.200942   (Cheese, Coffee Powder)
# 24  0.202140         (Cheese, Yougurt)
# 25  0.205812     (Coffee Powder, Ghee)
# 26  0.200543    (Coffee Powder, Lassi)
# 27  0.201022     (Coffee Powder, Milk)
# 28  0.203976  (Coffee Powder, Yougurt)
# 29  0.200463             (Ghee, Lassi)
# 30  0.200463              (Ghee, Milk)
# 31  0.201421            (Ghee, Panner)
# 32  0.200862             (Ghee, Sugar)
# 33  0.202698             (Lassi, Milk)
# 34  0.205652            (Lassi, Sweet)
# 35  0.204614             (Milk, Sugar)
# 36  0.200543             (Sweet, Milk)
# 37  0.200623           (Yougurt, Milk)
# 38  0.201900          (Yougurt, Sugar)

# %% [markdown]
# # **FP-Growth**

# %%
start = time.time()
df_fpgrowth = fpgrowth(df, min_support=0.2, use_colnames=True)
snapshot = tracemalloc.take_snapshot()
done = time.time()
elapsed = done - start
mem_use = calculate_mem_use(snapshot, func="fpgrowth")
print("Mem. use : %1.f B" %(mem_use))
print("Elapsed Time : ",elapsed," sn")
df_fpgrowth
# Out:
# Mem. use : 2608 B
# Elapsed Time :  0.46457576751708984  sn
#      support                  itemsets
# 0   0.439885                    (Ghee)
# 1   0.439805           (Coffee Powder)
# 2   0.439326                 (Yougurt)
# 3   0.437570                  (Butter)
# 4   0.437171                  (Cheese)
# 5   0.433658                   (Lassi)
# 6   0.429746              (Tea Powder)
# 7   0.437809                   (Bread)
# 8   0.434616                  (Panner)
# 9   0.437730                   (Sweet)
# 10  0.437650                   (Sugar)
# 11  0.441162                    (Milk)
# 12  0.200463              (Ghee, Milk)
# 13  0.205812     (Coffee Powder, Ghee)
# 14  0.201022     (Coffee Powder, Milk)
# 15  0.203976  (Coffee Powder, Yougurt)
# 16  0.200623           (Yougurt, Milk)
# 17  0.201980            (Butter, Ghee)
# 18  0.201900         (Butter, Yougurt)
# 19  0.205253           (Butter, Sugar)
# 20  0.203018           (Butter, Sweet)
# 21  0.202140         (Cheese, Yougurt)
# 22  0.200942   (Cheese, Coffee Powder)
# 23  0.201980           (Cheese, Bread)
# 24  0.200543    (Coffee Powder, Lassi)
# 25  0.200463             (Ghee, Lassi)
# 26  0.202698             (Lassi, Milk)
# 27  0.205652            (Lassi, Sweet)
# 28  0.200064            (Lassi, Bread)
# 29  0.201820    (Coffee Powder, Bread)
# 30  0.200942             (Milk, Bread)
# 31  0.200144          (Yougurt, Bread)
# 32  0.203577           (Panner, Bread)
# 33  0.201421            (Ghee, Panner)
# 34  0.200543             (Sweet, Milk)
# 35  0.202698            (Sweet, Bread)
# 36  0.201900          (Yougurt, Sugar)
# 37  0.204614             (Milk, Sugar)
# 38  0.200862             (Ghee, Sugar)

# %% [markdown]
# # **ECLAT**
#
# When we use association_rules method with the metric = "support" it uses ECLAT algorithm.
#
# see https://github.com/Nikronic/Machine-Learning-Models/blob/master/Part%205%20-%20Association%20Rule%20Learning/Section%2017%20-%20Eclat/eclat.py

# %%
start = time.time()
df_eclat = association_rules(df_apriori, metric='support',min_threshold= 0.2)
snapshot = tracemalloc.take_snapshot()
done = time.time()
elapsed = done - start
mem_use = calculate_mem_use(snapshot, func="association_rules")
print("Mem. use : %1.f B" %(mem_use))
print("Elapsed Time : ",elapsed," sn")
df_eclat
# Out:
# Mem. use : 33464 B
# Elapsed Time :  0.010829687118530273  sn
#         antecedents      consequents  antecedent support  consequent support  \
# 0          (Cheese)          (Bread)            0.437171            0.437809
# 1           (Bread)         (Cheese)            0.437809            0.437171
# 2   (Coffee Powder)          (Bread)            0.439805            0.437809
# 3           (Bread)  (Coffee Powder)            0.437809            0.439805
# 4           (Lassi)          (Bread)            0.433658            0.437809
# 5           (Bread)          (Lassi)            0.437809            0.433658
# 6            (Milk)          (Bread)            0.441162            0.437809
# 7           (Bread)           (Milk)            0.437809            0.441162
# 8          (Panner)          (Bread)            0.434616            0.437809
# 9           (Bread)         (Panner)            0.437809            0.434616
# 10          (Sweet)          (Bread)            0.437730            0.437809
# 11          (Bread)          (Sweet)            0.437809            0.437730
# 12        (Yougurt)          (Bread)            0.439326            0.437809
# 13          (Bread)        (Yougurt)            0.437809            0.439326
# 14         (Butter)           (Ghee)            0.437570            0.439885
# 15           (Ghee)         (Butter)            0.439885            0.437570
# 16         (Butter)          (Sugar)            0.437570            0.437650
# 17          (Sugar)         (Butter)            0.437650            0.437570
# 18         (Butter)          (Sweet)            0.437570            0.437730
# 19          (Sweet)         (Butter)            0.437730            0.437570
# 20         (Butter)        (Yougurt)            0.437570            0.439326
# 21        (Yougurt)         (Butter)            0.439326            0.437570
# 22         (Cheese)  (Coffee Powder)            0.437171            0.439805
# 23  (Coffee Powder)         (Cheese)            0.439805            0.437171
# 24         (Cheese)        (Yougurt)            0.437171            0.439326
# 25        (Yougurt)         (Cheese)            0.439326            0.437171
# 26  (Coffee Powder)           (Ghee)            0.439805            0.439885
# 27           (Ghee)  (Coffee Powder)            0.439885            0.439805
# 28  (Coffee Powder)          (Lassi)            0.439805            0.433658
# 29          (Lassi)  (Coffee Powder)            0.433658            0.439805
# 30  (Coffee Powder)           (Milk)            0.439805            0.441162
# 31           (Milk)  (Coffee Powder)            0.441162            0.439805
# 32  (Coffee Powder)        (Yougurt)            0.439805            0.439326
# 33        (Yougurt)  (Coffee Powder)            0.439326            0.439805
# 34           (Ghee)          (Lassi)            0.439885            0.433658
# 35          (Lassi)           (Ghee)            0.433658            0.439885
# 36           (Ghee)           (Milk)            0.439885            0.441162
# 37           (Milk)           (Ghee)            0.441162            0.439885
# 38           (Ghee)         (Panner)            0.439885            0.434616
# 39         (Panner)           (Ghee)            0.434616            0.439885
# 40           (Ghee)          (Sugar)            0.439885            0.437650
# 41          (Sugar)           (Ghee)            0.437650            0.439885
# 42          (Lassi)           (Milk)            0.433658            0.441162
# 43           (Milk)          (Lassi)            0.441162            0.433658
# 44          (Lassi)          (Sweet)            0.433658            0.437730
# 45          (Sweet)          (Lassi)            0.437730            0.433658
# 46           (Milk)          (Sugar)            0.441162            0.437650
# 47          (Sugar)           (Milk)            0.437650            0.441162
# 48          (Sweet)           (Milk)            0.437730            0.441162
# 49           (Milk)          (Sweet)            0.441162            0.437730
